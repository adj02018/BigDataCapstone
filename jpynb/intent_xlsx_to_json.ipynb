# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.7/site-packages (3.0.5)
# Requirement already satisfied: jdcal in /opt/conda/lib/python3.7/site-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.7/site-packages (from openpyxl) (1.0.1)

# %%
import openpyxl

# %%
# 한 건의 대화에 대한 정보를 담는 객체입니다.

class Conversation:
    # 질문(Question), 응답(Answer) 두 변수로 구성됩니다.
    def __init__(self, contentName, contentType, question, answer):
        self.contentName = contentName
        self.contentType = contentType
        self.question = question
        self.answer = answer

    def __str__(self):
        return "질문: " + self.question + "\n답변: " + self.answer + "\n"

# %%
# 영어 대화 데이터가 담긴 엑셀 파일을 엽니다.
wb = openpyxl.load_workbook('input.xlsx')

# 활성 시트를 얻습니다.
ws = wb.active
conversations = []

# 시트 내에 존재하는 모든 영어 대화 데이터를 객체로 담습니다.
for r in ws.rows:
    c = Conversation(r[0].value, r[1].value, r[2].value, r[3].value)
    conversations.append(c)

wb.close()

for c in conversations:
    print(str(c))

# 모든 대화 내용을 출력합니다.
for c in conversations:
    print(str(c))

print('총 ', len(conversations), '개의 대화가 존재합니다.')
# Out:
# 질문: [과목명] 몇시야?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 교시
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 몇 교시야?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 언제입니까?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 언제야?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 몇시니?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 입니까?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 언제
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 어디야?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디니?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디있어?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 몇 호야?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 몇호야?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디쪽?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디있습니까?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디에
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디에 있습니까?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디로
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디로 가면될까?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 강의실
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 강의실 어디
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 누구
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 누구셔?
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 누구?
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 교수님
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 교수님 누구입니까?
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 교수
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 교수 누구
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명]
# 답변: [과목명]는 [과목 구분] [과목 학점] 학점 과목이며, [교수님 이름] 교수님이 수업 맡으십니다.
#
# 질문: [과목명] 학점
# 답변: [과목명]의 학점은 [과목 구분] [과목 학점]으로 구성되어 있습니다.
#
# 질문: [과목명] 몇 학점
# 답변: [과목명]의 학점은 [과목 구분] [과목 학점]으로 구성되어 있습니다.
#
# 질문: [과목명] 학점 몇
# 답변: [과목명]의 학점은 [과목 구분] [과목 학점]으로 구성되어 있습니다.
#
# 질문: [과목명] 수업코드
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 수업번호
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 과목코드
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 과목번호
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 강의번호
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 강의코드
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [교수명] 연구실
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디에
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디에 있어?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디니?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디있어?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실어디
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실어디?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디에
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디에?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디에 있어?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디에 있습니까?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 수업
# 답변: [교수명] 교수님의 수업은 [교수 강좌명] 입니다.
#
# 질문: [교수명] 수업이 뭐야?
# 답변: [교수명] 교수님의 수업은 [교수 강좌명] 입니다.
#
# 질문: [교수명] 이메일
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일주소
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일 주소
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일뭐야?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일 뭐야?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일주소 뭐야
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일 주소 무엇
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일 주소 무엇이니?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일주소
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일 주소
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일뭐야?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일 뭐야?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일주소 뭐야
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일 주소 무엇
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일 주소 무엇이니?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 전화번호
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전화번호뭐야
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전화번호 뭐야?
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전화번호 무엇
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전화번호 무엇이니?
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번뭐야
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번 뭐야?
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번 무엇
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번 무엇이니?
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [과목명] 몇시야?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 교시
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 몇 교시야?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 언제입니까?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 언제야?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 몇시니?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 입니까?
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 언제
# 답변: 해당 [과목명]는 [과목 요일] [과목 교시(시간)] 입니다.
#
# 질문: [과목명] 어디야?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디니?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디있어?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 몇 호야?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 몇호야?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디쪽?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디있습니까?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디에
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디에 있습니까?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디로
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 어디로 가면될까?
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 강의실
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 강의실 어디
# 답변: 해당 [과목명] 수업은 [과목 강의실]에 있습니다.
#
# 질문: [과목명] 누구
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 누구셔?
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 누구?
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 교수님
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 교수님 누구입니까?
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 교수
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명] 교수 누구
# 답변: 해당 [과목명] 수업 맡으신 [교수님 이름]교수님 입니다.
#
# 질문: [과목명]
# 답변: [과목명]는 [과목 구분] [과목 학점] 학점 과목이며, [교수님 이름] 교수님이 수업 맡으십니다.
#
# 질문: [과목명] 학점
# 답변: [과목명]의 학점은 [과목 구분] [과목 학점]으로 구성되어 있습니다.
#
# 질문: [과목명] 몇 학점
# 답변: [과목명]의 학점은 [과목 구분] [과목 학점]으로 구성되어 있습니다.
#
# 질문: [과목명] 학점 몇
# 답변: [과목명]의 학점은 [과목 구분] [과목 학점]으로 구성되어 있습니다.
#
# 질문: [과목명] 수업코드
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 수업번호
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 과목코드
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 과목번호
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 강의번호
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [과목명] 강의코드
# 답변: [과목명]의 과목번호는 [과목번호] 입니다.
#
# 질문: [교수명] 연구실
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디에
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디에 있어?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디니?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 어디있어?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실어디
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실어디?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디에
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디에?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디에 있어?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 연구실 어디에 있습니까?
# 답변: [교수명] 교수님의 연구실은 [교수 연구실명] 입니다.
#
# 질문: [교수명] 수업
# 답변: [교수명] 교수님의 수업은 [교수 강좌명] 입니다.
#
# 질문: [교수명] 수업이 뭐야?
# 답변: [교수명] 교수님의 수업은 [교수 강좌명] 입니다.
#
# 질문: [교수명] 이메일
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일주소
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일 주소
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일뭐야?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일 뭐야?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일주소 뭐야
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일 주소 무엇
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 이메일 주소 무엇이니?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일주소
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일 주소
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일뭐야?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일 뭐야?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일주소 뭐야
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일 주소 무엇
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 메일 주소 무엇이니?
# 답변: [교수명] 교수님의 이메일 주소는 [교수명 이메일주소명] 입니다.
#
# 질문: [교수명] 전화번호
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전화번호뭐야
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전화번호 뭐야?
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전화번호 무엇
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전화번호 무엇이니?
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번뭐야
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번 뭐야?
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번 무엇
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 질문: [교수명] 전번 무엇이니?
# 답변: [교수명] 교수님의 전화번호는 [교수명 전화번호] 입니다.
#
# 총  80 개의 대화가 존재합니다.

# %%
# 파일로 출력하기

i = 1

# 출력, 입력 값 JSON 파일을 생성합니다.

prev = str(conversations[0].contentName) + str(conversations[0].contentType)
f = open(prev + '.json', 'w', encoding='UTF-8')
f.write('{ "id": "10d3155d-4468-4118-8f5d-15009af446d0", "name": "' + prev + '", "auto": true, "contexts": [], "responses": [ { "resetContexts": false, "affectedContexts": [], "parameters": [], "messages": [ { "type": 0, "lang": "ko", "speech": "' + conversations[0].answer + '" } ], "defaultResponsePlatforms": {}, "speech": [] } ], "priority": 500000, "webhookUsed": false, "webhookForSlotFilling": false, "fallbackIntent": false, "events": [] }')
f.close()
f = open(prev + '_usersays_ko.json', 'w', encoding='UTF-8')
f.write("[")
f.write('{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "' + conversations[0].question + '", "userDefined": false } ], "isTemplate": false, "count": 0 },')



while True:
    if i >= len(conversations):
        f.write("]")
        f.close()
        break;
    c = conversations[i]
    if prev == str(c.contentName) + str(c.contentType):
        f.write('{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "' + c.question + '", "userDefined": false } ], "isTemplate": false, "count": 0 },')
    
    else:
        f.write("]")
        f.close()
        # 출력, 입력 값 JSON 파일을 생성합니다.
        
        prev = str(c.contentName) + str(c.contentType)
        f = open(prev + '.json', 'w', encoding='UTF-8')
        f.write('{ "id": "10d3155d-4468-4118-8f5d-15009af446d0", "name": "' + prev + '", "auto": true, "contexts": [], "responses": [ { "resetContexts": false, "affectedContexts": [], "parameters": [], "messages": [ { "type": 0, "lang": "ko", "speech": "' + c.answer + '" } ], "defaultResponsePlatforms": {}, "speech": [] } ], "priority": 500000, "webhookUsed": false, "webhookForSlotFilling": false, "fallbackIntent": false, "events": [] }')
        f.close()
        f = open(prev + '_usersays_ko.json', 'w', encoding='UTF-8')
        f.write("[")
        f.write('{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "' + c.question + '", "userDefined": false } ], "isTemplate": false, "count": 0 },')
    i = i + 1

    
i = 0
fileindex = []
new_list = []
while True:
    if i >= len(conversations):
        break
        
    fileindex.append(str(conversations[i].contentName) + str(conversations[i].contentType))
    i= i+1


for v in fileindex:
    if v not in new_list:
        new_list.append(v)

for prevo in new_list:
    f2 = open(prevo + '_usersays_ko.json', 'r', encoding='UTF-8')
    line = f2.readline()
    sub = line.rstrip(',]') + ']'
    f2.close()
    f1 = open(prevo + '_usersays_ko.json', 'w', encoding='UTF-8')
    f1.write(sub)
    f1.close()

# %%
#
# 아래부터는 실험용 코드입니다. 컴파일 안하셔도됩니다.
#

i = 0
fileindex = []
new_list = []
while True:
    if i >= len(conversations):
        break
        
    print(str(conversations[i].contentName) + str(conversations[i].contentType))
    fileindex.append(str(conversations[i].contentName) + str(conversations[i].contentType))
    i= i+1
    
print(fileindex)

for v in fileindex:
    if v not in new_list:
        new_list.append(v)
print(new_list)
# Out:
# Family1
# Family2
# ['Family1', 'Family2']
# ['Family1', 'Family2']

# %%
f = open(prev + '_usersays_ko.json', 'r', encoding='UTF-8')
line = f.readline()
print(line)
sub = line.rstrip(',]')
print(sub+']')
f.close()
# Out:
# [{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "[과목명] 몇시야?", "userDefined": false } ], "isTemplate": false, "count": 0 },]
# [{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "[과목명] 몇시야?", "userDefined": false } ], "isTemplate": false, "count": 0 }]

# %%
f = open(prev + '_usersays_ko.json', 'w', encoding='UTF-8')
f.write('test')
f.close()

# %%
i = 1
while True:
    if i >= len(conversations):
        break
    
    c = conversations[i]
    prevo = str(c.contentName) + str(c.contentType)
    
    f2 = open(prevo + '_usersays_ko.json', 'r', encoding='UTF-8')
    line = f2.readline()
    sub = line.rstrip(',]') + ']'
    f2.close()
    f1 = open(prevo + '_usersays_ko.json', 'w', encoding='UTF-8')
    f1.write(sub)
    f1.close()
    
    i = i + 1
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-60-c2ef2e40d428> in <module>
#       4         break
#       5
# ----> 6     c = conversations[i]
#       7     prevo = str(c.contentName) + str(c.contentType)
#       8
#
# IndexError: list index out of range

# %%
sub
# Out:
# '[{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "[과목명] 몇시야?", "userDefined": false } ], "isTemplate": false, "count": 0 }'
